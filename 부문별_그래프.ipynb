# %% [markdown]
# <a href="https://colab.research.google.com/github/cocobyun/project3/blob/main/%EB%B6%80%EB%AC%B8%EB%B3%84_%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a bar chart for 3Q sales with adjusted bar width
plt.figure(figsize=(14, 8))  # 차트 크기를 더 크게 조정
bar_width = 0.5  # 막대의 두께 설정
bars = plt.bar(naver_sales_data['네이버 3Q 매출'], naver_sales_data['3Q 매출 (억원)'], color='lightpink', width=bar_width)

# Annotate the YoY growth percentage next to each bar
for bar, yoy in zip(bars, naver_sales_data['YoY (%)']):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval+200, f'{yoy}%', va='bottom', ha='center', fontsize=14)  # 글씨 크기 조정

# Adjust labels and title with increased fontsize and custom spacing
plt.xlabel('부문별', fontproperties=fontprop, fontsize=16, labelpad=20)  # x축 타이틀과 그래프 간의 간격 조정
plt.ylabel('3Q 매출 (억원)', fontproperties=fontprop, fontsize=16, labelpad=15)
plt.title('네이버 3Q 매출', fontproperties=fontprop, fontsize=20, pad=30)  # 제목과 차트 간의 간격 조정

# Set y-axis limit
plt.ylim(0, 12000)  # y축의 최대값을 12000으로 설정
plt.gca().xaxis.set_tick_params(pad=10)
plt.tight_layout()

# 그래프 표시
plt.xticks(fontproperties=fontprop, fontsize=14)  # x축 눈금 글씨 크기 조정
plt.yticks(fontproperties=fontprop, fontsize=14)  # y축 눈금 글씨 크기 조정
plt.show()
# Out:
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 47019 (\N{HANGUL SYLLABLE RAES}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 54268 (\N{HANGUL SYLLABLE POM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 52964 (\N{HANGUL SYLLABLE KEO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 47672 (\N{HANGUL SYLLABLE MEO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 54592 (\N{HANGUL SYLLABLE PIN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 53580 (\N{HANGUL SYLLABLE TE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 52968 (\N{HANGUL SYLLABLE KEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 53584 (\N{HANGUL SYLLABLE TEN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 52768 (\N{HANGUL SYLLABLE CEU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 53364 (\N{HANGUL SYLLABLE KEUL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from current font.
#   plt.tight_layout()
# <ipython-input-23-f3d79a421369>:19: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   plt.tight_layout()
